# %% [markdown]
# TASK 23
#  Training, validation, and test sets

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense

# %%
# Load the MNIST dataset
(X_train, y_train), (X_test, y_test) = mnist.load_data()

# Split the training data into training and validation sets
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %%
# Normalize the pixel values
X_train = X_train / 255.0
X_val = X_val / 255.0
X_test = X_test / 255.0

# %%
# Define the model architecture
model = Sequential()
model.add(Dense(64, activation='relu', input_shape=(784,)))
model.add(Dense(10, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %%
# Train the model and save the training history
history = model.fit(X_train.reshape(-1, 784), y_train, validation_data=(X_val.reshape(-1, 784), y_val), epochs=10, batch_size=32)
# Out:
# Epoch 1/10
# 1500/1500 [==============================] - 6s 3ms/step - loss: 0.3394 - accuracy: 0.9030 - val_loss: 0.2019 - val_accuracy: 0.9432
# Epoch 2/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1662 - accuracy: 0.9524 - val_loss: 0.1557 - val_accuracy: 0.9552
# Epoch 3/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.1214 - accuracy: 0.9646 - val_loss: 0.1224 - val_accuracy: 0.9617
# Epoch 4/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0946 - accuracy: 0.9722 - val_loss: 0.1110 - val_accuracy: 0.9657
# Epoch 5/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0777 - accuracy: 0.9769 - val_loss: 0.1015 - val_accuracy: 0.9705
# Epoch 6/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0636 - accuracy: 0.9808 - val_loss: 0.0996 - val_accuracy: 0.9704
# Epoch 7/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0539 - accuracy: 0.9840 - val_loss: 0.0999 - val_accuracy: 0.9689
# Epoch 8/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0451 - accuracy: 0.9860 - val_loss: 0.0906 - val_accuracy: 0.9731
# Epoch 9/10
# 1500/1500 [==============================] - 4s 3ms/step - loss: 0.0396 - accuracy: 0.9876 - val_loss: 0.0947 - val_accuracy: 0.9721
# Epoch 10/10
# 1500/1500 [==============================] - 5s 3ms/step - loss: 0.0330 - accuracy: 0.9901 - val_loss: 0.1042 - val_accuracy: 0.9711

# %%
# Plot the validation score during training
import matplotlib.pyplot as plt

plt.plot(history.history['val_accuracy'])
plt.title('Validation Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.show()
